# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusinghal/IMS/blob/main/IMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
unit_price={}
product={}
stock={}

details = open("stock.txt","r")

no_items  = int((details.readline()).rstrip("\n"))

for i in range(0,no_items):
    line  = (details.readline()).rstrip("\n")
    x1,x2 = line.split("#")
    x1=int(x1)
    x2=float(x2)
    unit_price.update({x1: x2})

for i in range(0,no_items):
    line  = (details.readline()).rstrip("\n")
    x1,x2 = line.split("#")
    x1=int(x1)
    product.update({x1: x2})

for i in range(0,no_items):
    line  = (details.readline()).rstrip("\n")
    x1,x2 = line.split("#")
    x1=int(x1)
    x2=int(x2)
    stock.update({x1: x2})

details.close()

cart=[]

c="y" 


print("Welcome to IMS")
print()
print("A-Add an item")
print("R-Remove an item")
print("E-Edit an item")
print("P-Purchase an item")
print("L-List all items")
print("Q-Quit")
print()


total_cost=0 
flag=0 


while(c!= "q" or c!= "Q"):
    c= input("What would you like to do? ")
    
    if(c=="q" or c=="Q"):
        break
        
    elif(c=="A" or c=="a"):#Add an item
        p_no = int(input("Enter part number: "))
        p_pr = float(input("Enter part price: "))
        p_desc = input("Enter part product: ")
        p_stock = int(input("Enter part stock: "))
        
        m=0
        for i in range(0,len(unit_price)):
            if(p_no in unit_price):
                p_no+=1
                m=1
        if(m==1):
            print()
            print("That part number already exists :(, changing value to ",p_no)
                
        unit_price.update({p_no: p_pr})
        product.update({p_no: p_desc})
        if(p_stock > -1):
            stock.update({p_no: p_stock})
        else:
            p_stock = 0
            stock.update({p_no: p_stock})
            print("The stock of an item cannot be negative, the stock has been set to 0.")
        print()
        print("Part number: ",p_no," product: ",product.get(p_no)," Price: ",unit_price.get(p_no)," Stock: ",stock.get(p_no))
        print("Part was added successfully!")
        print()
        
    elif(c=="E" or c=="e"):#Edit an item
        print()
        p_no = int(input("Enter part number: "))
        if(p_no in unit_price):
            p_pr = float(input("Enter part price: "))
            p_desc = input("Enter part product: ")
            p_stock = int(input("Enter part stock: "))
                
            unit_price.update({p_no: p_pr})
            product.update({p_no: p_desc})
            stock.update({p_no: p_stock})
            
        else:
            print("That item does not exist, to add an item use a")
        print()
    
            
    elif(c=="R" or c=="r"):#Remove an item
        print()
        p_no = int(input("Enter part number: "))
        if(p_no in unit_price):
            are_you_sure = input("Are you sure you want to remove that item(y/n)? ")
            if(are_you_sure=="y" or are_you_sure=="Y"):
                unit_price.pop(p_no)
                product.pop(p_no)
                stock.pop(p_no)
                print("Item successfully removed!")
            print()
        else:
            print("Sorry, we don't have such an item!")
            print()
        
    elif(c=="L" or c=="l"):#List all items
        print()
        print("Parts and their prices: ",unit_price)
        print("products: ",product)
        print("Stock left of Item: ",stock)
        print()

        
    elif(c=="P" or c=="p"):#Purchase a part
        print()
        p_no = int(input("Enter Part number: "))
        if(p_no in unit_price):
            if(flag==1):
                flag=0
            stock_current = stock.get(p_no)
            if(stock_current>0):
                stock_current = stock.get(p_no)
                stock[p_no] = stock_current-1
                item_price = unit_price.get(p_no)
                total_cost = total_cost+item_price
                print(product.get(p_no),"added to cart: ","$",item_price)
                cart.append(p_no)#Stores item in cart
            else:
                print("Sorry! We don't have that item in stock!")
        else:
                print("Sorry! We don't have such an item!")
        print()
        

        
    else:
        print()
        print("Invalid Input")
        print()

if(total_cost>0 and flag==0):
    print()
    print("You bought: ",cart)
    print("Total: ","$",round(total_cost,2))
    tax= round(0.13*total_cost,2)
    print("Tax is 13%: ","$",tax)
    total = round(total_cost+tax,2)
    print("After Tax: ","$",total)
    
print()

details = open("stock.txt","w")
no_items=len(unit_price)
details.write(str(no_items)+"\n")
for i in range(0,no_items):
    details.write(str(i+1)+"#"+str(unit_price[i+1])+"\n")
    
for i in range(0,no_items):
    details.write(str(i+1)+"#"+product[i+1]+"\n")
    
for i in range(0,no_items):
    details.write(str(i+1)+"#"+str(stock[i+1])+"\n")

details.close()
# Out:
# Welcome to IMS
#
# A-Add an item
# R-Remove an item
# E-Edit an item
# P-Purchase an item
# L-List all items
# Q-Quit
#
# What would you like to do? q

# %%
import json

# %%
details = open("stock.txt","r")
dis = details.read()
details.close()
js = json.dumps(dis)

fd = open("stock.json",'w')
fd.write(js)
fd.close()

fd = open("stock.json",'r')
txt = fd.read()
fd.close()

record = json.loads(txt)
record
# Out:
# '4\n1#100.0\n2#200.0\n3#150.0\n4#199.0\n1#Bottle\n2#Steel Bottel\n3#Premium Bottle\n4#Imported Bottle\n1#44\n2#18\n3#34\n4#66\n'
